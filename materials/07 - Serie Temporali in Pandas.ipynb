# %% [markdown]
# # Serie temporali in Pandas
#
# - Panoramica sui concetti generali di "tempo" in Pandas
# - Oggetti Timestamp e DatetimeIndex e i costruttori : Timestamp(), to_datetime() e date_range()
# - OggettiPeriod e PeriodIndex e i costruttori : Period() e Period_range()
# - Oggetti Timedelta e TimedeltaIndex e i costruttori : Timedelta(), to_timedelta() e timedelta_range()
# - metodi e attributi comuni alle serie temporali
# - leggere serie temporali da un file tramite parametro parse_dates
# - Slicing delle serie temporali con gli operatori loc[] e iloc[]
# - metodo reindex() e resample()
# - Esercizio!

# %% [markdown]
# ## Panoramica sui concetti generali di "tempo" in Pandas
#
# Ci sono 3 concetti principali legati al "tempo" che vengono gestiti dalla libreria Pandas:
#
# 1) **Date Time**: legato al concetto di data / orario, simile al concetto di datetime.datetime della libreria standard datetime. I suoi oggetti principali sono:
#                         - Timestamp
#                         - DatetimeIndex
#
# 2) **Time span**: legato al concetto di arco temporale, periodo con un inizio, una fine e una frequenza di ripetizione.
#  gli oggetti principali sono:
#                         - Period
#                         - PeriodIndex
#
#
# 3) **Time delta**: "differenze in tempo" assoluta. I suoi oggetti principali sono:
#                         - Timedelta
#                         - TimedeltaIndex

# %% [markdown]
# ## Timestamp e DatetimeIndex
#
# - L'oggetto **Timestamp** rappresenta una singola marca temporale. Equivalente dell'oggetto *datetime* nella libreria standard *datetime* di Python, ma e' molto piu' flessibile (cosi come le *Series* hanno molta piu' flessibilita' rispetto alle *liste* in Python)
#
# - L'oggetto **DatetimeIndex** non e' altro che una collezione di oggetti Timestamp

# %%
import pandas as pd

# %% [markdown]
# Esistono 3 costruttori principali per gli oggetti Timestamp e DatetimeIndex, vediamoli uno alla volta:

# %% [markdown]
# ##### Costruttore Timestamp()

# %%
# passiamo una stringa

pd.Timestamp("30/10/1983") # primo parametro e' il valore che deve essere convertito in oggetto Timestamp
# Out:
# Timestamp('1983-10-30 00:00:00')

# %%
# tutte queste stringhe sono valide e convertite allo stesso modo

print(pd.Timestamp("30-10-1983"))

print(pd.Timestamp("30 Oct, 1983"))

print(pd.Timestamp("30-10/1983"))

print(pd.Timestamp("30-10-83"))
# Out:
# 1983-10-30 00:00:00
# 1983-10-30 00:00:00
# 1983-10-30 00:00:00
# 1983-10-30 00:00:00

# %%
# passiamo un intero (o un float)

pd.Timestamp(436380629, unit = "ns")

# Se non specifico il parametro "unit", Il tempo viene rappresentato come offset in nanosecondi
# rispetto alla mezzanotte (UTC) del 1º gennaio 1970 (detto "epoch").
# Out:
# Timestamp('1970-01-01 00:00:00.436380629')

# %%
# di solito si specifica unit = "s"

pd.Timestamp(436380629.5, unit = "s")
# Out:
# Timestamp('1983-10-30 16:50:29.500000')

# %%
# passiamo un intero inteso come anno, mese, giorno, ora, minuti, secondi

pd.Timestamp(2020, 5, 9, 18, 44, 43)
# Out:
# Timestamp('2020-05-09 18:44:43')

# %%
#oppure specifico cosa rappresenta ogni intero

pd.Timestamp(year = 2020, month = 5, day = 9, hour = 18, minute = 44, second= 43)
# Out:
# Timestamp('2020-05-09 18:44:43')

# %% [markdown]
# ###### Costruttore to_datetime()
# - piu' flessibile rispetto a pd.Timestamp()
#
# - riceve come argomento da convertire in un oggetto Timestamp diversi tipi di formati, non solo int, float, stringhe e datetime object, ma anche liste, array, Series e Dataframes

# %%
print(pd.to_datetime("30/10/1983"))

print(pd.to_datetime(1589049883, unit = "s"))
# Out:
# 1983-10-30 00:00:00
# 2020-05-09 18:44:43

# %%
# passo una lista

pd.to_datetime(["30/10/1983", "30/10/1984"])
# ottengo un DatetimeIndex perche' ho una collezione / lista di oggetti Timestamp
# Out:
# DatetimeIndex(['1983-10-30', '1984-10-30'], dtype='datetime64[ns]', freq=None)

# %%
# se passo una lista al costruttore pd.Timestamp ottengo un errore

#pd.Timestamp(["30/10/1983", "30/10/1984"])

# %%
# Creo una Series con delle strighe che rappresentano delle date (ma hanno sempre dtype object)

pd.Series(data = ["1981", "30/10/1983", "30/10/1984", "15/02/1999 08:45"])
# Out:
# 0                1981
# 1          30/10/1983
# 2          30/10/1984
# 3    15/02/1999 08:45
# dtype: object

# %%
# passo La Series al costruttore to_datetime() e ottengo la conversione in una serie temporale

pd.to_datetime(pd.Series(data = ["1981", "30/10/1983", "30/10/1984", "15/02/1999 08:45"]))
# Out:
# 0   1981-01-01 00:00:00
# 1   1983-10-30 00:00:00
# 2   1984-10-30 00:00:00
# 3   1999-02-15 08:45:00
# dtype: datetime64[ns]

# %%
# Creo una Series con delle strighe dove non tutte rappresentano delle date reali

date = pd.Series(data = ["1981", "30/10/1983", "30/10/1984", "35/13/1999 08:45"])

# %%
# posso settare il parametro "errors"

pd.to_datetime(date, errors = "coerce")
# Out:
# 0   1981-01-01
# 1   1983-10-30
# 2   1984-10-30
# 3          NaT
# dtype: datetime64[ns]

# %% [markdown]
# ## Costruttore date_range()
# - utilizzato per costruire DateimeIndex (quindi una "collezione" di oggetti Timestamp)
#
# - ha 3 parametri fondamentali ("start", "end" e "periods"), di cui almeno due devono essere settati

# %%
import pandas as pd

# utilizzo "start" e "end"
pd.date_range(start = "2019/01/01", end = "31/12/2019", freq = "QS-FEB")
# Out:
# DatetimeIndex(['2019-02-01', '2019-05-01', '2019-08-01', '2019-11-01'], dtype='datetime64[ns]', freq='QS-FEB')

# %% [markdown]
# alias per il parametro "freq": https://pandas.pydata.org/pandas-docs/stable/user_guide/timeseries.html#timeseries-offset-aliases

# %%
# utilizzo "start" e "periods"

pd.date_range(start = "2019/01/01", periods = 56, freq = "W-Tue")
# Out:
# DatetimeIndex(['2019-01-01', '2019-01-08', '2019-01-15', '2019-01-22',
#                '2019-01-29', '2019-02-05', '2019-02-12', '2019-02-19',
#                '2019-02-26', '2019-03-05', '2019-03-12', '2019-03-19',
#                '2019-03-26', '2019-04-02', '2019-04-09', '2019-04-16',
#                '2019-04-23', '2019-04-30', '2019-05-07', '2019-05-14',
#                '2019-05-21', '2019-05-28', '2019-06-04', '2019-06-11',
#                '2019-06-18', '2019-06-25', '2019-07-02', '2019-07-09',
#                '2019-07-16', '2019-07-23', '2019-07-30', '2019-08-06',
#                '2019-08-13', '2019-08-20', '2019-08-27', '2019-09-03',
#                '2019-09-10', '2019-09-17', '2019-09-24', '2019-10-01',
#                '2019-10-08', '2019-10-15', '2019-10-22', '2019-10-29',
#                '2019-11-05', '2019-11-12', '2019-11-19', '2019-11-26',
#                '2019-12-03', '2019-12-10', '2019-12-17', '2019-12-24',
#                '2019-12-31', '2020-01-07', '2020-01-14', '2020-01-21'],
#               dtype='datetime64[ns]', freq='W-TUE')

# %%
# utilizzo "end" e "periods"

pd.date_range(end = "2020/01/01", periods = 12, freq = "N")
# Out:
# DatetimeIndex(['2019-12-31 23:59:59.999999989',
#                '2019-12-31 23:59:59.999999990',
#                '2019-12-31 23:59:59.999999991',
#                '2019-12-31 23:59:59.999999992',
#                '2019-12-31 23:59:59.999999993',
#                '2019-12-31 23:59:59.999999994',
#                '2019-12-31 23:59:59.999999995',
#                '2019-12-31 23:59:59.999999996',
#                '2019-12-31 23:59:59.999999997',
#                '2019-12-31 23:59:59.999999998',
#                '2019-12-31 23:59:59.999999999',
#                          '2020-01-01 00:00:00'],
#               dtype='datetime64[ns]', freq='N')

# %%
# utilizzo tutti e 3
# non posso settare "freq"

pd.date_range(start = "2019/01/01", end = "2019/12/31", periods = 364)
# Out:
# DatetimeIndex([          '2019-01-01 00:00:00',
#                '2019-01-02 00:03:58.016528925',
#                '2019-01-03 00:07:56.033057851',
#                '2019-01-04 00:11:54.049586776',
#                '2019-01-05 00:15:52.066115702',
#                '2019-01-06 00:19:50.082644628',
#                '2019-01-07 00:23:48.099173553',
#                '2019-01-08 00:27:46.115702479',
#                '2019-01-09 00:31:44.132231405',
#                '2019-01-10 00:35:42.148760330',
#                ...
#                '2019-12-21 23:24:17.851239672',
#                '2019-12-22 23:28:15.867768596',
#                '2019-12-23 23:32:13.884297524',
#                '2019-12-24 23:36:11.900826448',
#                '2019-12-25 23:40:09.917355372',
#                '2019-12-26 23:44:07.933884300',
#                '2019-12-27 23:48:05.950413224',
#                '2019-12-28 23:52:03.966942152',
#                '2019-12-29 23:56:01.983471076',
#                          '2019-12-31 00:00:00'],
#               dtype='datetime64[ns]', length=364, freq=None)

# %% [markdown]
# ## Period e PeriodIndex
# - per "period" si intende un periodo temporale, ad esempio un intero giorno, un intero mese, o un anno, ecc..
# - da non confondere con il concetto di "Timestamp" che si riferisce ad una singola marca temporale, ad un preciso momento nel tempo
#
# - PeriodIndex e' una collezione di oggetti "period" cosi come DatetimeIndex e' una collezione di oggetti "Timestamp"

# %%
import pandas as pd

# %%
pd.Timestamp("2020-01-01") # si riferisce ad un specifico "momento"
# Out:
# Timestamp('2020-01-01 00:00:00')

# %% [markdown]
# #### Costruttore Period()

# %%
pd.Period("2020-01-01") # si riferisce a "tutto il giorno"
# Out:
# Period('2020-01-01', 'D')

# %%
a = pd.Period("2020-01-01")

a.end_time
# Out:
# Timestamp('2020-01-01 23:59:59.999999999')

# %% [markdown]
# #### Costruttore period_range()
#
# - simile a date_range()

# %%
pd.period_range(start = "2019-01-01", end = "2019-12-31", freq = "D")
# Out:
# PeriodIndex(['2019-01-01', '2019-01-02', '2019-01-03', '2019-01-04',
#              '2019-01-05', '2019-01-06', '2019-01-07', '2019-01-08',
#              '2019-01-09', '2019-01-10',
#              ...
#              '2019-12-22', '2019-12-23', '2019-12-24', '2019-12-25',
#              '2019-12-26', '2019-12-27', '2019-12-28', '2019-12-29',
#              '2019-12-30', '2019-12-31'],
#             dtype='period[D]', length=365, freq='D')

# %% [markdown]
# ###### posso passare da PeriodIndex a datetimeIndex usando to_timestamp()

# %%
pd.period_range(start = "2019-01-01", end = "2019-12-31", freq = "D").to_timestamp()
# Out:
# DatetimeIndex(['2019-01-01', '2019-01-02', '2019-01-03', '2019-01-04',
#                '2019-01-05', '2019-01-06', '2019-01-07', '2019-01-08',
#                '2019-01-09', '2019-01-10',
#                ...
#                '2019-12-22', '2019-12-23', '2019-12-24', '2019-12-25',
#                '2019-12-26', '2019-12-27', '2019-12-28', '2019-12-29',
#                '2019-12-30', '2019-12-31'],
#               dtype='datetime64[ns]', length=365, freq='D')

# %% [markdown]
# ##### oppure il contrario usando metodo to_period()

# %%
pd.date_range(start = "2019-01-01", end = "2019-12-31", freq = "D").to_period()
# Out:
# PeriodIndex(['2019-01-01', '2019-01-02', '2019-01-03', '2019-01-04',
#              '2019-01-05', '2019-01-06', '2019-01-07', '2019-01-08',
#              '2019-01-09', '2019-01-10',
#              ...
#              '2019-12-22', '2019-12-23', '2019-12-24', '2019-12-25',
#              '2019-12-26', '2019-12-27', '2019-12-28', '2019-12-29',
#              '2019-12-30', '2019-12-31'],
#             dtype='period[D]', length=365, freq='D')

# %% [markdown]
# ## Timedelta e TimedeltaIndex
# - legati al concetto generale di **Time delta**: "differenze in tempo" assoluta.
# - in pratica la differenza in termini di "tempo" tra due momenti precisi
# - anche in questo caso, TimedeltaIndex non e' altro che una collezione di oggetti "timedelta"

# %%
import pandas as pd
data1 = pd.Timestamp("2020-01-11 12:00:00")

# %%
data2 = pd.Timestamp("2020-01-01 10:00:00")

# %%
data2 - data1    # differenza in tempo (assoluta) tra due precisi istanti temporali
# Out:
# Timedelta('-11 days +22:00:00')

# %% [markdown]
# #### Costruttore Timedelta()

# %%
# dobbiamo specificare il "delta" in termini di tempo (settimane, giorni, ore,..)- ma non mesi e anni!


pd.Timedelta( days = 1, minutes = 50)
# Out:
# Timedelta('1 days 00:50:00')

# %% [markdown]
# #### Costruttore to_timedelta()
# - similmente al costruttore to_datetime() accetta anche liste o series (al contrario di "Timedelta()")

# %%
pd.to_timedelta(['1 days 01:10:22', '45s', '1 W 2 days'])
# Out:
# TimedeltaIndex(['1 days 01:10:22', '0 days 00:00:45', '9 days 00:00:00'], dtype='timedelta64[ns]', freq=None)

# %%
# cosi come to_datetime() ha il parametro "errors"

pd.to_timedelta(['1 days 01:10:22', '45s', '1 W 2 days', 'ciao'], errors = "coerce")
# Out:
# TimedeltaIndex(['1 days 01:10:22', '0 days 00:00:45', '9 days 00:00:00', NaT], dtype='timedelta64[ns]', freq=None)

# %% [markdown]
# #### Costruttore timedelta_range()

# %%
pd.timedelta_range(start='1 W', periods=5)
# Out:
# TimedeltaIndex(['7 days', '8 days', '9 days', '10 days', '11 days'], dtype='timedelta64[ns]', freq='D')

# %%
pd.timedelta_range(start='1 W', periods=5, closed = "right")
# Out:
# TimedeltaIndex(['8 days', '9 days', '10 days', '11 days'], dtype='timedelta64[ns]', freq='D')

# %%
pd.timedelta_range(start='1 day', end='2 days', freq='6H')
# Out:
# TimedeltaIndex(['1 days 00:00:00', '1 days 06:00:00', '1 days 12:00:00',
#                 '1 days 18:00:00', '2 days 00:00:00'],
#                dtype='timedelta64[ns]', freq='6H')

# %%
pd.timedelta_range(start='1 day', end='20 days', periods=4) # la frequenza viene "spaziata linearmente"
# Out:
# TimedeltaIndex(['1 days 00:00:00', '7 days 08:00:00', '13 days 16:00:00',
#                 '20 days 00:00:00'],
#                dtype='timedelta64[ns]', freq=None)

# %% [markdown]
# ## Accedere agli attributi temporali tramite .dt

# %%
import pandas as pd
pd.date_range(start = "2020/01/01", end = "2020-12-31")
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-04',
#                '2020-01-05', '2020-01-06', '2020-01-07', '2020-01-08',
#                '2020-01-09', '2020-01-10',
#                ...
#                '2020-12-22', '2020-12-23', '2020-12-24', '2020-12-25',
#                '2020-12-26', '2020-12-27', '2020-12-28', '2020-12-29',
#                '2020-12-30', '2020-12-31'],
#               dtype='datetime64[ns]', length=366, freq='D')

# %%
s = pd.Series(pd.date_range(start = "2020/01/01", end = "2020-12-31"))
s
# Out:
# 0     2020-01-01
# 1     2020-01-02
# 2     2020-01-03
# 3     2020-01-04
# 4     2020-01-05
#          ...
# 361   2020-12-27
# 362   2020-12-28
# 363   2020-12-29
# 364   2020-12-30
# 365   2020-12-31
# Length: 366, dtype: datetime64[ns]

# %%
df = s.to_frame(name = "2020")
df
# Out:
#           2020
# 0   2020-01-01
# 1   2020-01-02
# 2   2020-01-03
# 3   2020-01-04
# 4   2020-01-05
# ..         ...
# 361 2020-12-27
# 362 2020-12-28
# 363 2020-12-29
# 364 2020-12-30
# 365 2020-12-31
#
# [366 rows x 1 columns]

# %%
df["giorno"]  = df["2020"].dt.day_name()
df
# Out:
#           2020     giorno
# 0   2020-01-01  Wednesday
# 1   2020-01-02   Thursday
# 2   2020-01-03     Friday
# 3   2020-01-04   Saturday
# 4   2020-01-05     Sunday
# ..         ...        ...
# 361 2020-12-27     Sunday
# 362 2020-12-28     Monday
# 363 2020-12-29    Tuesday
# 364 2020-12-30  Wednesday
# 365 2020-12-31   Thursday
#
# [366 rows x 2 columns]

# %%
df["2020"].dt.year
# Out:
# 0      2020
# 1      2020
# 2      2020
# 3      2020
# 4      2020
#        ...
# 361    2020
# 362    2020
# 363    2020
# 364    2020
# 365    2020
# Name: 2020, Length: 366, dtype: int64

# %% [markdown]
# ## Metodi e Attributi di oggetti Timestamps
# - il metodo di accesso **.dt** ci permette di fare operazioni su delle series che contengono oggetti datetime
# - ma io posso accedere direttamente a degli attributi e metodi quando ho oggetti Timestamp (o DatetimeIndex)

# %%
# riprendo esempio lezione precedente

import pandas as pd

df= pd.Series(data = "valore random", index = pd.date_range(start = "2020/01/01", end = "2020-12-31")).to_frame("2020")
df
# Out:
#                      2020
# 2020-01-01  valore random
# 2020-01-02  valore random
# 2020-01-03  valore random
# 2020-01-04  valore random
# 2020-01-05  valore random
# ...                   ...
# 2020-12-27  valore random
# 2020-12-28  valore random
# 2020-12-29  valore random
# 2020-12-30  valore random
# 2020-12-31  valore random
#
# [366 rows x 1 columns]

# %%
df.index
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-04',
#                '2020-01-05', '2020-01-06', '2020-01-07', '2020-01-08',
#                '2020-01-09', '2020-01-10',
#                ...
#                '2020-12-22', '2020-12-23', '2020-12-24', '2020-12-25',
#                '2020-12-26', '2020-12-27', '2020-12-28', '2020-12-29',
#                '2020-12-30', '2020-12-31'],
#               dtype='datetime64[ns]', length=366, freq='D')

# %%
giorno = df.index[0]
giorno
# Out:
# Timestamp('2020-01-01 00:00:00', freq='D')

# %%
giorno.day
# Out:
# 1

# %%
giorno.is_month_end
# Out:
# False

# %%
giorno.day_name()
# Out:
# 'Wednesday'

# %%
giorno.month_name()
# Out:
# 'January'

# %% [markdown]
# *posso usare questi attributi e metodi sull'intero oggetto DatetimeIndex*

# %%
df.index.day_name()
# Out:
# Index(['Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday', 'Monday',
#        'Tuesday', 'Wednesday', 'Thursday', 'Friday',
#        ...
#        'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday',
#        'Monday', 'Tuesday', 'Wednesday', 'Thursday'],
#       dtype='object', length=366)

# %%
df.insert(0, column = "day_name", value = df.index.day_name())
df
# Out:
#              day_name           2020
# 2020-01-01  Wednesday  valore random
# 2020-01-02   Thursday  valore random
# 2020-01-03     Friday  valore random
# 2020-01-04   Saturday  valore random
# 2020-01-05     Sunday  valore random
# ...               ...            ...
# 2020-12-27     Sunday  valore random
# 2020-12-28     Monday  valore random
# 2020-12-29    Tuesday  valore random
# 2020-12-30  Wednesday  valore random
# 2020-12-31   Thursday  valore random
#
# [366 rows x 2 columns]

# %%
df[df["day_name"] == "Friday"]
# Out:
#            day_name           2020
# 2020-01-03   Friday  valore random
# 2020-01-10   Friday  valore random
# 2020-01-17   Friday  valore random
# 2020-01-24   Friday  valore random
# 2020-01-31   Friday  valore random
# 2020-02-07   Friday  valore random
# 2020-02-14   Friday  valore random
# 2020-02-21   Friday  valore random
# 2020-02-28   Friday  valore random
# 2020-03-06   Friday  valore random
# 2020-03-13   Friday  valore random
# 2020-03-20   Friday  valore random
# 2020-03-27   Friday  valore random
# 2020-04-03   Friday  valore random
# 2020-04-10   Friday  valore random
# 2020-04-17   Friday  valore random
# 2020-04-24   Friday  valore random
# 2020-05-01   Friday  valore random
# 2020-05-08   Friday  valore random
# 2020-05-15   Friday  valore random
# 2020-05-22   Friday  valore random
# 2020-05-29   Friday  valore random
# 2020-06-05   Friday  valore random
# 2020-06-12   Friday  valore random
# 2020-06-19   Friday  valore random
# 2020-06-26   Friday  valore random
# 2020-07-03   Friday  valore random
# 2020-07-10   Friday  valore random
# 2020-07-17   Friday  valore random
# 2020-07-24   Friday  valore random
# 2020-07-31   Friday  valore random
# 2020-08-07   Friday  valore random
# 2020-08-14   Friday  valore random
# 2020-08-21   Friday  valore random
# 2020-08-28   Friday  valore random
# 2020-09-04   Friday  valore random
# 2020-09-11   Friday  valore random
# 2020-09-18   Friday  valore random
# 2020-09-25   Friday  valore random
# 2020-10-02   Friday  valore random
# 2020-10-09   Friday  valore random
# 2020-10-16   Friday  valore random
# 2020-10-23   Friday  valore random
# 2020-10-30   Friday  valore random
# 2020-11-06   Friday  valore random
# 2020-11-13   Friday  valore random
# 2020-11-20   Friday  valore random
# 2020-11-27   Friday  valore random
# 2020-12-04   Friday  valore random
# 2020-12-11   Friday  valore random
# 2020-12-18   Friday  valore random
# 2020-12-25   Friday  valore random

# %% [markdown]
# ## Leggere una serie temporale da un file esterno

# %%
import pandas as pd

# %%
df = pd.read_csv("FB.csv")
df
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2019-05-16  185.050003  188.580002  185.050003  186.990005  186.990005
# 1    2019-05-17  184.839996  187.580002  184.279999  185.300003  185.300003
# 2    2019-05-20  181.880005  184.229996  181.369995  182.720001  182.720001
# 3    2019-05-21  184.570007  185.699997  183.889999  184.820007  184.820007
# 4    2019-05-22  184.729996  186.740005  183.610001  185.320007  185.320007
# ..          ...         ...         ...         ...         ...         ...
# 248  2020-05-11  210.889999  215.000000  210.369995  213.179993  213.179993
# 249  2020-05-12  213.289993  215.279999  210.000000  210.100006  210.100006
# 250  2020-05-13  209.429993  210.779999  202.110001  205.100006  205.100006
# 251  2020-05-14  202.559998  206.929993  200.690002  206.809998  206.809998
# 252  2020-05-15  205.270004  211.339996  204.119995  210.880005  210.880005
#
#        Volume
# 0    12953100
# 1    10485400
# 2    10352000
# 3     7502800
# 4     9213800
# ..        ...
# 248  12911900
# 249  14704600
# 250  20684600
# 251  17178900
# 252  19375200
#
# [253 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 253 entries, 0 to 252
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       253 non-null    object
#  1   Open       253 non-null    float64
#  2   High       253 non-null    float64
#  3   Low        253 non-null    float64
#  4   Close      253 non-null    float64
#  5   Adj Close  253 non-null    float64
#  6   Volume     253 non-null    int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 14.0+ KB

# %%
df.set_index("Date", inplace = True)

# %%
df.index
# Out:
# Index(['2019-05-16', '2019-05-17', '2019-05-20', '2019-05-21', '2019-05-22',
#        '2019-05-23', '2019-05-24', '2019-05-28', '2019-05-29', '2019-05-30',
#        ...
#        '2020-05-04', '2020-05-05', '2020-05-06', '2020-05-07', '2020-05-08',
#        '2020-05-11', '2020-05-12', '2020-05-13', '2020-05-14', '2020-05-15'],
#       dtype='object', name='Date', length=253)

# %%
df.index = pd.to_datetime(df.index)

# %% [markdown]
# Trasformo la mia serie temporale direttamente col metodo _read_csv

# %%
df = pd.read_csv("FB.csv", parse_dates= ["Date"], index_col = "Date")
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2019-05-16  185.050003  188.580002  185.050003  186.990005  186.990005
# 2019-05-17  184.839996  187.580002  184.279999  185.300003  185.300003
# 2019-05-20  181.880005  184.229996  181.369995  182.720001  182.720001
# 2019-05-21  184.570007  185.699997  183.889999  184.820007  184.820007
# 2019-05-22  184.729996  186.740005  183.610001  185.320007  185.320007
# ...                ...         ...         ...         ...         ...
# 2020-05-11  210.889999  215.000000  210.369995  213.179993  213.179993
# 2020-05-12  213.289993  215.279999  210.000000  210.100006  210.100006
# 2020-05-13  209.429993  210.779999  202.110001  205.100006  205.100006
# 2020-05-14  202.559998  206.929993  200.690002  206.809998  206.809998
# 2020-05-15  205.270004  211.339996  204.119995  210.880005  210.880005
#
#               Volume
# Date
# 2019-05-16  12953100
# 2019-05-17  10485400
# 2019-05-20  10352000
# 2019-05-21   7502800
# 2019-05-22   9213800
# ...              ...
# 2020-05-11  12911900
# 2020-05-12  14704600
# 2020-05-13  20684600
# 2020-05-14  17178900
# 2020-05-15  19375200
#
# [253 rows x 6 columns]

# %%
df.index
# Out:
# DatetimeIndex(['2019-05-16', '2019-05-17', '2019-05-20', '2019-05-21',
#                '2019-05-22', '2019-05-23', '2019-05-24', '2019-05-28',
#                '2019-05-29', '2019-05-30',
#                ...
#                '2020-05-04', '2020-05-05', '2020-05-06', '2020-05-07',
#                '2020-05-08', '2020-05-11', '2020-05-12', '2020-05-13',
#                '2020-05-14', '2020-05-15'],
#               dtype='datetime64[ns]', name='Date', length=253, freq=None)

# %% [markdown]
# ## Leggere una serie temporale da un file esterno parte 2

# %%
import pandas as pd
pd.read_csv("FB.csv", parse_dates = ["Date"])
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 0   2019-05-16  185.050003  188.580002  185.050003  186.990005  186.990005
# 1   2019-05-17  184.839996  187.580002  184.279999  185.300003  185.300003
# 2   2019-05-20  181.880005  184.229996  181.369995  182.720001  182.720001
# 3   2019-05-21  184.570007  185.699997  183.889999  184.820007  184.820007
# 4   2019-05-22  184.729996  186.740005  183.610001  185.320007  185.320007
# ..         ...         ...         ...         ...         ...         ...
# 248 2020-05-11  210.889999  215.000000  210.369995  213.179993  213.179993
# 249 2020-05-12  213.289993  215.279999  210.000000  210.100006  210.100006
# 250 2020-05-13  209.429993  210.779999  202.110001  205.100006  205.100006
# 251 2020-05-14  202.559998  206.929993  200.690002  206.809998  206.809998
# 252 2020-05-15  205.270004  211.339996  204.119995  210.880005  210.880005
#
#        Volume
# 0    12953100
# 1    10485400
# 2    10352000
# 3     7502800
# 4     9213800
# ..        ...
# 248  12911900
# 249  14704600
# 250  20684600
# 251  17178900
# 252  19375200
#
# [253 rows x 7 columns]

# %%
df= pd.read_csv("FB2.csv", parse_dates = ["Date"])
df
# Out:
#                  Date        Open        High         Low       Close  \
# 0    2019-05-16 08_AM  185.050003  188.580002  185.050003  186.990005
# 1    2019-05-17 08_AM  184.839996  187.580002  184.279999  185.300003
# 2    2019-05-20 08_AM  181.880005  184.229996  181.369995  182.720001
# 3    2019-05-21 08_AM  184.570007  185.699997  183.889999  184.820007
# 4    2019-05-22 08_AM  184.729996  186.740005  183.610001  185.320007
# ..                ...         ...         ...         ...         ...
# 248  2020-05-11 08_AM  210.889999  215.000000  210.369995  213.179993
# 249  2020-05-12 08_AM  213.289993  215.279999  210.000000  210.100006
# 250  2020-05-13 08_AM  209.429993  210.779999  202.110001  205.100006
# 251  2020-05-14 08_AM  202.559998  206.929993  200.690002  206.809998
# 252  2020-05-15 08_AM  205.270004  211.339996  204.119995  210.880005
#
#       Adj Close    Volume
# 0    186.990005  12953100
# 1    185.300003  10485400
# 2    182.720001  10352000
# 3    184.820007   7502800
# 4    185.320007   9213800
# ..          ...       ...
# 248  213.179993  12911900
# 249  210.100006  14704600
# 250  205.100006  20684600
# 251  206.809998  17178900
# 252  210.880005  19375200
#
# [253 rows x 7 columns]

# %%
df.info()

# la mia colonna "Date" e' ancora un dtype object
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 253 entries, 0 to 252
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       253 non-null    object
#  1   Open       253 non-null    float64
#  2   High       253 non-null    float64
#  3   Low        253 non-null    float64
#  4   Close      253 non-null    float64
#  5   Adj Close  253 non-null    float64
#  6   Volume     253 non-null    int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 14.0+ KB

# %% [markdown]
# proviamo ad usare il metodo to_datetime()

# %%
pd.to_datetime(df["Date"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\arrays\datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object)
#    1857         try:
# -> 1858             values, tz_parsed = conversion.datetime_to_datetime64(data)
#    1859             # If tzaware, these values represent unix timestamps, so we
#
# pandas\_libs\tslibs\conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ParserError                               Traceback (most recent call last)
# <ipython-input-62-a389c144bbd3> in <module>
# ----> 1 pd.to_datetime(df["Date"])
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#     726             result = arg.map(cache_array)
#     727         else:
# --> 728             values = convert_listlike(arg._values, format)
#     729             result = arg._constructor(values, index=arg.index, name=arg.name)
#     730     elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     445             errors=errors,
#     446             require_iso8601=require_iso8601,
# --> 447             allow_object=True,
#     448         )
#     449
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\arrays\datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object)
#    1861             return values.view("i8"), tz_parsed
#    1862         except (ValueError, TypeError):
# -> 1863             raise e
#    1864
#    1865     if tz_parsed is not None:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\arrays\datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object)
#    1852             dayfirst=dayfirst,
#    1853             yearfirst=yearfirst,
# -> 1854             require_iso8601=require_iso8601,
#    1855         )
#    1856     except ValueError as e:
#
# pandas\_libs\tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas\_libs\tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas\_libs\tslib.pyx in pandas._libs.tslib.array_to_datetime_object()
#
# pandas\_libs\tslib.pyx in pandas._libs.tslib.array_to_datetime_object()
#
# pandas\_libs\tslibs\parsing.pyx in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\dateutil\parser\_parser.py in parse(timestr, parserinfo, **kwargs)
#    1372         return parser(parserinfo).parse(timestr, **kwargs)
#    1373     else:
# -> 1374         return DEFAULTPARSER.parse(timestr, **kwargs)
#    1375
#    1376
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\dateutil\parser\_parser.py in parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     647
#     648         if res is None:
# --> 649             raise ParserError("Unknown string format: %s", timestr)
#     650
#     651         if len(res) == 0:
#
# ParserError: Unknown string format: 2019-05-16 08_AM

# %% [markdown]
# Devo formattare le stringhe nella colonna "Date" in maniera opportuna:
#
# - "2019-05-16 08_AM" e' nel formato anno-mese-giorno ora_AM
# - il tipo di formattazione lo trovate qui: https://docs.python.org/3/library/datetime.html#strftime-and-strptime-behavior

# %%
pd.to_datetime(df["Date"], format = "%Y-%m-%d %I_%p")
# Out:
# 0     2019-05-16 08:00:00
# 1     2019-05-17 08:00:00
# 2     2019-05-20 08:00:00
# 3     2019-05-21 08:00:00
# 4     2019-05-22 08:00:00
#               ...
# 248   2020-05-11 08:00:00
# 249   2020-05-12 08:00:00
# 250   2020-05-13 08:00:00
# 251   2020-05-14 08:00:00
# 252   2020-05-15 08:00:00
# Name: Date, Length: 253, dtype: datetime64[ns]

# %% [markdown]
# Posso fare questa operazione direttamente alla lettura del file

# %%
import datetime

# %%
df = pd.read_csv("FB2.csv", parse_dates = ["Date"], date_parser = lambda x: datetime.datetime.strptime(x, "%Y-%m-%d %I_%p"))
df
# Out:
#                    Date        Open        High         Low       Close  \
# 0   2019-05-16 08:00:00  185.050003  188.580002  185.050003  186.990005
# 1   2019-05-17 08:00:00  184.839996  187.580002  184.279999  185.300003
# 2   2019-05-20 08:00:00  181.880005  184.229996  181.369995  182.720001
# 3   2019-05-21 08:00:00  184.570007  185.699997  183.889999  184.820007
# 4   2019-05-22 08:00:00  184.729996  186.740005  183.610001  185.320007
# ..                  ...         ...         ...         ...         ...
# 248 2020-05-11 08:00:00  210.889999  215.000000  210.369995  213.179993
# 249 2020-05-12 08:00:00  213.289993  215.279999  210.000000  210.100006
# 250 2020-05-13 08:00:00  209.429993  210.779999  202.110001  205.100006
# 251 2020-05-14 08:00:00  202.559998  206.929993  200.690002  206.809998
# 252 2020-05-15 08:00:00  205.270004  211.339996  204.119995  210.880005
#
#       Adj Close    Volume
# 0    186.990005  12953100
# 1    185.300003  10485400
# 2    182.720001  10352000
# 3    184.820007   7502800
# 4    185.320007   9213800
# ..          ...       ...
# 248  213.179993  12911900
# 249  210.100006  14704600
# 250  205.100006  20684600
# 251  206.809998  17178900
# 252  210.880005  19375200
#
# [253 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 253 entries, 0 to 252
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       253 non-null    datetime64[ns]
#  1   Open       253 non-null    float64
#  2   High       253 non-null    float64
#  3   Low        253 non-null    float64
#  4   Close      253 non-null    float64
#  5   Adj Close  253 non-null    float64
#  6   Volume     253 non-null    int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 14.0 KB

# %% [markdown]
# ## loc[] e iloc[] con oggetti DatetimeIndex

# %%
import pandas as pd
df = pd.read_csv("FB.csv", parse_dates= ["Date"], index_col = "Date")
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2019-05-16  185.050003  188.580002  185.050003  186.990005  186.990005
# 2019-05-17  184.839996  187.580002  184.279999  185.300003  185.300003
# 2019-05-20  181.880005  184.229996  181.369995  182.720001  182.720001
# 2019-05-21  184.570007  185.699997  183.889999  184.820007  184.820007
# 2019-05-22  184.729996  186.740005  183.610001  185.320007  185.320007
# ...                ...         ...         ...         ...         ...
# 2020-05-11  210.889999  215.000000  210.369995  213.179993  213.179993
# 2020-05-12  213.289993  215.279999  210.000000  210.100006  210.100006
# 2020-05-13  209.429993  210.779999  202.110001  205.100006  205.100006
# 2020-05-14  202.559998  206.929993  200.690002  206.809998  206.809998
# 2020-05-15  205.270004  211.339996  204.119995  210.880005  210.880005
#
#               Volume
# Date
# 2019-05-16  12953100
# 2019-05-17  10485400
# 2019-05-20  10352000
# 2019-05-21   7502800
# 2019-05-22   9213800
# ...              ...
# 2020-05-11  12911900
# 2020-05-12  14704600
# 2020-05-13  20684600
# 2020-05-14  17178900
# 2020-05-15  19375200
#
# [253 rows x 6 columns]

# %%
df.index
# Out:
# DatetimeIndex(['2019-05-16', '2019-05-17', '2019-05-20', '2019-05-21',
#                '2019-05-22', '2019-05-23', '2019-05-24', '2019-05-28',
#                '2019-05-29', '2019-05-30',
#                ...
#                '2020-05-04', '2020-05-05', '2020-05-06', '2020-05-07',
#                '2020-05-08', '2020-05-11', '2020-05-12', '2020-05-13',
#                '2020-05-14', '2020-05-15'],
#               dtype='datetime64[ns]', name='Date', length=253, freq=None)

# %% [markdown]
# **Estrazione tramite posizione**: *iloc[]*
# - valgono le stesse regole viste per gli oggetti "Index"

# %%
df.iloc[0]
# Out:
# Open         1.850500e+02
# High         1.885800e+02
# Low          1.850500e+02
# Close        1.869900e+02
# Adj Close    1.869900e+02
# Volume       1.295310e+07
# Name: 2019-05-16 00:00:00, dtype: float64

# %%
df.iloc[0:2] # estremo destro escluso
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2019-05-16  185.050003  188.580002  185.050003  186.990005  186.990005
# 2019-05-17  184.839996  187.580002  184.279999  185.300003  185.300003
#
#               Volume
# Date
# 2019-05-16  12953100
# 2019-05-17  10485400

# %%
df.iloc[-3:-1] # estremo destro escluso
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-05-13  209.429993  210.779999  202.110001  205.100006  205.100006
# 2020-05-14  202.559998  206.929993  200.690002  206.809998  206.809998
#
#               Volume
# Date
# 2020-05-13  20684600
# 2020-05-14  17178900

# %%
df.iloc[[0,1,-1]]
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2019-05-16  185.050003  188.580002  185.050003  186.990005  186.990005
# 2019-05-17  184.839996  187.580002  184.279999  185.300003  185.300003
# 2020-05-15  205.270004  211.339996  204.119995  210.880005  210.880005
#
#               Volume
# Date
# 2019-05-16  12953100
# 2019-05-17  10485400
# 2020-05-15  19375200

# %% [markdown]
# **Estrazione tramite etichetta (index label)**: *.loc[]*

# %%
df.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2019-05-16  185.050003  188.580002  185.050003  186.990005  186.990005
# 2019-05-17  184.839996  187.580002  184.279999  185.300003  185.300003
# 2019-05-20  181.880005  184.229996  181.369995  182.720001  182.720001
# 2019-05-21  184.570007  185.699997  183.889999  184.820007  184.820007
# 2019-05-22  184.729996  186.740005  183.610001  185.320007  185.320007
#
#               Volume
# Date
# 2019-05-16  12953100
# 2019-05-17  10485400
# 2019-05-20  10352000
# 2019-05-21   7502800
# 2019-05-22   9213800

# %%
df.loc["2019-05-17"]
# Out:
# Open         1.848400e+02
# High         1.875800e+02
# Low          1.842800e+02
# Close        1.853000e+02
# Adj Close    1.853000e+02
# Volume       1.048540e+07
# Name: 2019-05-17 00:00:00, dtype: float64

# %%
df.loc["2019-05-17": "2019-05-22"] # estremo destro incluso
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2019-05-17  184.839996  187.580002  184.279999  185.300003  185.300003
# 2019-05-20  181.880005  184.229996  181.369995  182.720001  182.720001
# 2019-05-21  184.570007  185.699997  183.889999  184.820007  184.820007
# 2019-05-22  184.729996  186.740005  183.610001  185.320007  185.320007
#
#               Volume
# Date
# 2019-05-17  10485400
# 2019-05-20  10352000
# 2019-05-21   7502800
# 2019-05-22   9213800

# %%
df.loc["2019-06"] # ottengo tutte le osservazioni relative al mese di maggio 2019
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2019-06-03  175.000000  175.050003  161.009995  164.149994  164.149994
# 2019-06-04  163.710007  168.279999  160.839996  167.500000  167.500000
# 2019-06-05  167.479996  168.720001  164.630005  168.169998  168.169998
# 2019-06-06  168.300003  169.699997  167.229996  168.330002  168.330002
# 2019-06-07  170.169998  173.869995  168.839996  173.350006  173.350006
# 2019-06-10  174.750000  177.860001  173.800003  174.820007  174.820007
# 2019-06-11  178.479996  179.979996  176.789993  178.100006  178.100006
# 2019-06-12  178.380005  179.270004  172.880005  175.039993  175.039993
# 2019-06-13  175.529999  178.029999  174.610001  177.470001  177.470001
# 2019-06-14  180.509995  181.839996  180.000000  181.330002  181.330002
# 2019-06-17  185.009995  189.500000  184.410004  189.009995  189.009995
# 2019-06-18  194.000000  194.529999  187.279999  188.470001  188.470001
# 2019-06-19  187.000000  188.100006  184.550003  187.479996  187.479996
# 2019-06-20  190.949997  191.160004  187.639999  189.529999  189.529999
# 2019-06-21  188.750000  192.000000  188.750000  191.139999  191.139999
# 2019-06-24  192.419998  193.979996  191.570007  192.600006  192.600006
# 2019-06-25  192.880005  193.139999  188.130005  188.839996  188.839996
# 2019-06-26  189.539993  190.759995  187.309998  187.660004  187.660004
# 2019-06-27  189.880005  198.880005  188.270004  189.500000  189.500000
# 2019-06-28  190.550003  193.199997  189.940002  193.000000  193.000000
#
#               Volume
# Date
# 2019-06-03  56059600
# 2019-06-04  46044300
# 2019-06-05  19758300
# 2019-06-06  12446400
# 2019-06-07  16917300
# 2019-06-10  14767900
# 2019-06-11  15266600
# 2019-06-12  17681500
# 2019-06-13  12253600
# 2019-06-14  16773700
# 2019-06-17  29459900
# 2019-06-18  37571400
# 2019-06-19  21417100
# 2019-06-20  14635700
# 2019-06-21  22751200
# 2019-06-24  15509000
# 2019-06-25  16750300
# 2019-06-26  12808600
# 2019-06-27  11159000
# 2019-06-28  16378900

# %%
df.loc["2020-01-01":] # tutte le osservazioni dopo il primo gennaio 2020
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-01-02  206.750000  209.789993  206.270004  209.779999  209.779999
# 2020-01-03  207.210007  210.399994  206.949997  208.669998  208.669998
# 2020-01-06  206.699997  212.779999  206.520004  212.600006  212.600006
# 2020-01-07  212.820007  214.580002  211.750000  213.059998  213.059998
# 2020-01-08  213.000000  216.240005  212.610001  215.220001  215.220001
# ...                ...         ...         ...         ...         ...
# 2020-05-11  210.889999  215.000000  210.369995  213.179993  213.179993
# 2020-05-12  213.289993  215.279999  210.000000  210.100006  210.100006
# 2020-05-13  209.429993  210.779999  202.110001  205.100006  205.100006
# 2020-05-14  202.559998  206.929993  200.690002  206.809998  206.809998
# 2020-05-15  205.270004  211.339996  204.119995  210.880005  210.880005
#
#               Volume
# Date
# 2020-01-02  12077100
# 2020-01-03  11188400
# 2020-01-06  17058900
# 2020-01-07  14912400
# 2020-01-08  13475000
# ...              ...
# 2020-05-11  12911900
# 2020-05-12  14704600
# 2020-05-13  20684600
# 2020-05-14  17178900
# 2020-05-15  19375200
#
# [94 rows x 6 columns]

# %% [markdown]
# Posso ottenere lo stesso risultato della cella di sopra col metodo **truncate()**

# %%
df.truncate(before = "2020-01-01")
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-01-02  206.750000  209.789993  206.270004  209.779999  209.779999
# 2020-01-03  207.210007  210.399994  206.949997  208.669998  208.669998
# 2020-01-06  206.699997  212.779999  206.520004  212.600006  212.600006
# 2020-01-07  212.820007  214.580002  211.750000  213.059998  213.059998
# 2020-01-08  213.000000  216.240005  212.610001  215.220001  215.220001
# ...                ...         ...         ...         ...         ...
# 2020-05-11  210.889999  215.000000  210.369995  213.179993  213.179993
# 2020-05-12  213.289993  215.279999  210.000000  210.100006  210.100006
# 2020-05-13  209.429993  210.779999  202.110001  205.100006  205.100006
# 2020-05-14  202.559998  206.929993  200.690002  206.809998  206.809998
# 2020-05-15  205.270004  211.339996  204.119995  210.880005  210.880005
#
#               Volume
# Date
# 2020-01-02  12077100
# 2020-01-03  11188400
# 2020-01-06  17058900
# 2020-01-07  14912400
# 2020-01-08  13475000
# ...              ...
# 2020-05-11  12911900
# 2020-05-12  14704600
# 2020-05-13  20684600
# 2020-05-14  17178900
# 2020-05-15  19375200
#
# [94 rows x 6 columns]

# %%
df.truncate(after = "2020-01-01")
# df.loc[:"2020-01-01"]
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2019-05-16  185.050003  188.580002  185.050003  186.990005  186.990005
# 2019-05-17  184.839996  187.580002  184.279999  185.300003  185.300003
# 2019-05-20  181.880005  184.229996  181.369995  182.720001  182.720001
# 2019-05-21  184.570007  185.699997  183.889999  184.820007  184.820007
# 2019-05-22  184.729996  186.740005  183.610001  185.320007  185.320007
# ...                ...         ...         ...         ...         ...
# 2019-12-24  206.300003  206.789993  205.000000  205.119995  205.119995
# 2019-12-26  205.570007  207.820007  205.309998  207.789993  207.789993
# 2019-12-27  208.669998  208.929993  206.589996  208.100006  208.100006
# 2019-12-30  207.860001  207.899994  203.899994  204.410004  204.410004
# 2019-12-31  204.000000  205.559998  203.600006  205.250000  205.250000
#
#               Volume
# Date
# 2019-05-16  12953100
# 2019-05-17  10485400
# 2019-05-20  10352000
# 2019-05-21   7502800
# 2019-05-22   9213800
# ...              ...
# 2019-12-24   6046300
# 2019-12-26   9350700
# 2019-12-27  10284200
# 2019-12-30  10524300
# 2019-12-31   8953500
#
# [159 rows x 6 columns]

# %%
df.loc[["2019-05-20", "2019-05-28"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-80-8a2f10293854> in <module>
# ----> 1 df.loc[["2019-05-20", "2019-05-28"]]
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1766
#    1767             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1768             return self._getitem_axis(maybe_callable, axis=axis)
#    1769
#    1770     def _is_scalar_access(self, key: Tuple):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1952                     raise ValueError("Cannot index with multidimensional key")
#    1953
# -> 1954                 return self._getitem_iterable(key, axis=axis)
#    1955
#    1956             # nested tuple slicing
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_iterable(self, key, axis)
#    1593         else:
#    1594             # A collection of keys
# -> 1595             keyarr, indexer = self._get_listlike_indexer(key, axis, raise_missing=False)
#    1596             return self.obj._reindex_with_indexers(
#    1597                 {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1551
#    1552         self._validate_read_indexer(
# -> 1553             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1554         )
#    1555         return keyarr, indexer
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1638             if missing == len(indexer):
#    1639                 axis_name = self.obj._get_axis_name(axis)
# -> 1640                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1641
#    1642             # We (temporarily) allow for some missing keys with .loc, except in
#
# KeyError: "None of [Index(['2019-05-20', '2019-05-28'], dtype='object', name='Date')] are in the [index]"

# %% [markdown]
# il KeyError di sopra mi dice che la mia lista e' un Index object, devo convertirla prima in un oggetto DatetimeIndex

# %%
pd.to_datetime(["2019-05-20", "2019-05-28"])
# Out:
# DatetimeIndex(['2019-05-20', '2019-05-28'], dtype='datetime64[ns]', freq=None)

# %%
df.loc[pd.to_datetime(["2019-05-20", "2019-05-28"])]
# Out:
#                   Open        High         Low       Close   Adj Close  \
# 2019-05-20  181.880005  184.229996  181.369995  182.720001  182.720001
# 2019-05-28  181.539993  184.710007  181.449997  184.309998  184.309998
#
#               Volume
# 2019-05-20  10352000
# 2019-05-28  14843300

# %% [markdown]
# ## metodo reindex()

# %%
import pandas as pd

df = pd.read_csv("FB.csv", parse_dates= ["Date"], index_col = "Date").round(2)
df
# Out:
#               Open    High     Low   Close  Adj Close    Volume
# Date
# 2019-05-16  185.05  188.58  185.05  186.99     186.99  12953100
# 2019-05-17  184.84  187.58  184.28  185.30     185.30  10485400
# 2019-05-20  181.88  184.23  181.37  182.72     182.72  10352000
# 2019-05-21  184.57  185.70  183.89  184.82     184.82   7502800
# 2019-05-22  184.73  186.74  183.61  185.32     185.32   9213800
# ...            ...     ...     ...     ...        ...       ...
# 2020-05-11  210.89  215.00  210.37  213.18     213.18  12911900
# 2020-05-12  213.29  215.28  210.00  210.10     210.10  14704600
# 2020-05-13  209.43  210.78  202.11  205.10     205.10  20684600
# 2020-05-14  202.56  206.93  200.69  206.81     206.81  17178900
# 2020-05-15  205.27  211.34  204.12  210.88     210.88  19375200
#
# [253 rows x 6 columns]

# %%
df.index.min()
# Out:
# Timestamp('2019-05-16 00:00:00')

# %%
df.index.max()
# Out:
# Timestamp('2020-05-15 00:00:00')

# %%
nuovo_indice = pd.date_range(start = df.index.min(), end = df.index.max(), freq = "D")

# %%
df.reindex(nuovo_indice, method = "ffill")
# Out:
#               Open    High     Low   Close  Adj Close    Volume
# 2019-05-16  185.05  188.58  185.05  186.99     186.99  12953100
# 2019-05-17  184.84  187.58  184.28  185.30     185.30  10485400
# 2019-05-18  184.84  187.58  184.28  185.30     185.30  10485400
# 2019-05-19  184.84  187.58  184.28  185.30     185.30  10485400
# 2019-05-20  181.88  184.23  181.37  182.72     182.72  10352000
# ...            ...     ...     ...     ...        ...       ...
# 2020-05-11  210.89  215.00  210.37  213.18     213.18  12911900
# 2020-05-12  213.29  215.28  210.00  210.10     210.10  14704600
# 2020-05-13  209.43  210.78  202.11  205.10     205.10  20684600
# 2020-05-14  202.56  206.93  200.69  206.81     206.81  17178900
# 2020-05-15  205.27  211.34  204.12  210.88     210.88  19375200
#
# [366 rows x 6 columns]

# %% [markdown]
# ## metodo resample()
# - utile per cambiare la "frequenza" di una serie temporale: ad esempio passare da una frequenza giornaliera ad una mensile
# - lavora in background in maniera simile al metodo groupby

# %%
import pandas as pd

df = pd.read_csv("FB.csv", parse_dates= ["Date"], index_col = "Date").round(2)
df
# Out:
#               Open    High     Low   Close  Adj Close    Volume
# Date
# 2019-05-16  185.05  188.58  185.05  186.99     186.99  12953100
# 2019-05-17  184.84  187.58  184.28  185.30     185.30  10485400
# 2019-05-20  181.88  184.23  181.37  182.72     182.72  10352000
# 2019-05-21  184.57  185.70  183.89  184.82     184.82   7502800
# 2019-05-22  184.73  186.74  183.61  185.32     185.32   9213800
# ...            ...     ...     ...     ...        ...       ...
# 2020-05-11  210.89  215.00  210.37  213.18     213.18  12911900
# 2020-05-12  213.29  215.28  210.00  210.10     210.10  14704600
# 2020-05-13  209.43  210.78  202.11  205.10     205.10  20684600
# 2020-05-14  202.56  206.93  200.69  206.81     206.81  17178900
# 2020-05-15  205.27  211.34  204.12  210.88     210.88  19375200
#
# [253 rows x 6 columns]

# %%
df = df.reindex(pd.date_range(df.index.min(), df.index.max(), freq = "D"), method = "ffill")
df
# Out:
#               Open    High     Low   Close  Adj Close    Volume
# 2019-05-16  185.05  188.58  185.05  186.99     186.99  12953100
# 2019-05-17  184.84  187.58  184.28  185.30     185.30  10485400
# 2019-05-18  184.84  187.58  184.28  185.30     185.30  10485400
# 2019-05-19  184.84  187.58  184.28  185.30     185.30  10485400
# 2019-05-20  181.88  184.23  181.37  182.72     182.72  10352000
# ...            ...     ...     ...     ...        ...       ...
# 2020-05-11  210.89  215.00  210.37  213.18     213.18  12911900
# 2020-05-12  213.29  215.28  210.00  210.10     210.10  14704600
# 2020-05-13  209.43  210.78  202.11  205.10     205.10  20684600
# 2020-05-14  202.56  206.93  200.69  206.81     206.81  17178900
# 2020-05-15  205.27  211.34  204.12  210.88     210.88  19375200
#
# [366 rows x 6 columns]

# %% [markdown]
# Passo da una frequenza giornaliera ad una mensile col metodo resample

# %%
mesi = df.resample("MS") # oggetto DatetimeIndexResampler (simile ad un oggetto groupby)

# %%
mesi.groups
# Out:
# {Timestamp('2019-05-01 00:00:00', freq='MS'): 16,
#  Timestamp('2019-06-01 00:00:00', freq='MS'): 46,
#  Timestamp('2019-07-01 00:00:00', freq='MS'): 77,
#  Timestamp('2019-08-01 00:00:00', freq='MS'): 108,
#  Timestamp('2019-09-01 00:00:00', freq='MS'): 138,
#  Timestamp('2019-10-01 00:00:00', freq='MS'): 169,
#  Timestamp('2019-11-01 00:00:00', freq='MS'): 199,
#  Timestamp('2019-12-01 00:00:00', freq='MS'): 230,
#  Timestamp('2020-01-01 00:00:00', freq='MS'): 261,
#  Timestamp('2020-02-01 00:00:00', freq='MS'): 290,
#  Timestamp('2020-03-01 00:00:00', freq='MS'): 321,
#  Timestamp('2020-04-01 00:00:00', freq='MS'): 351,
#  Timestamp('2020-05-01 00:00:00', freq='MS'): 366}

# %%
mesi.get_group('2019-08-31 00:00:00')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-92-856034a19cd1> in <module>
# ----> 1 mesi.get_group('2019-08-31 00:00:00')
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in get_group(self, name, obj)
#     684         inds = self._get_index(name)
#     685         if not len(inds):
# --> 686             raise KeyError(name)
#     687
#     688         return obj._take_with_is_copy(inds, axis=self.axis)
#
# KeyError: '2019-08-31 00:00:00'

# %%
mesi.last()
# Out:
#               Open    High     Low   Close  Adj Close    Volume
# 2019-05-01  180.28  180.54  177.16  177.47     177.47  15226500
# 2019-06-01  190.55  193.20  189.94  193.00     193.00  16378900
# 2019-07-01  196.95  198.76  192.68  194.23     194.23  14593500
# 2019-08-01  186.78  186.80  183.46  185.67     185.67  10774500
# 2019-09-01  177.87  178.67  176.85  178.08     178.08  10740000
# 2019-10-01  196.70  198.09  188.25  191.65     191.65  42286500
# 2019-11-01  201.60  203.80  201.21  201.64     201.64   7985200
# 2019-12-01  204.00  205.56  203.60  205.25     205.25   8953500
# 2020-01-01  208.43  208.69  201.06  201.91     201.91  31359900
# 2020-02-01  182.70  192.74  181.82  192.47     192.47  32583500
# 2020-03-01  165.48  170.93  164.20  166.80     166.80  23676300
# 2020-04-01  206.92  209.69  201.57  204.71     204.71  46230100
# 2020-05-01  205.27  211.34  204.12  210.88     210.88  19375200

# %%
mesi.mean()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# 2019-05-01  183.180625  184.981250  181.912500  182.990000  182.990000
# 2019-06-01  181.793667  184.025000  179.595333  181.935667  181.935667
# 2019-07-01  199.210645  201.475161  196.998065  199.582581  199.582581
# 2019-08-01  185.420645  187.095806  182.878387  184.556774  184.556774
# 2019-09-01  186.553667  187.662333  183.934667  185.648667  185.648667
# 2019-10-01  184.387742  186.573548  182.096774  184.438387  184.438387
# 2019-11-01  195.345667  197.042000  194.109333  195.825667  195.825667
# 2019-12-01  202.548065  203.706774  200.552258  202.157097  202.157097
# 2020-01-01  216.316452  217.969677  214.480968  216.468387  216.468387
# 2020-02-01  207.684138  210.101379  205.300345  207.808621  207.808621
# 2020-03-01  165.519032  170.464516  160.761290  166.280645  166.280645
# 2020-04-01  176.213333  178.798000  172.560000  176.320667  176.320667
# 2020-05-01  207.297333  210.686000  205.196667  208.132667  208.132667
#
#                   Volume
# 2019-05-01  1.068291e+07
# 2019-06-01  2.008352e+07
# 2019-07-01  1.572368e+07
# 2019-08-01  1.348829e+07
# 2019-09-01  1.362014e+07
# 2019-10-01  1.376772e+07
# 2019-11-01  1.289797e+07
# 2019-12-01  1.379381e+07
# 2020-01-01  1.530365e+07
# 2020-02-01  1.716465e+07
# 2020-03-01  2.955239e+07
# 2020-04-01  2.545984e+07
# 2020-05-01  1.940033e+07

# %% [markdown]
# L'output della cella precedente sembra che si riferisca ad un giorno preciso invece che a tutto il mese, proviamo un'altra strada:

# %%
df.resample("M", kind = "period").mean()
# Out:
#                Open        High         Low       Close   Adj Close  \
# 2019-05  183.180625  184.981250  181.912500  182.990000  182.990000
# 2019-06  181.793667  184.025000  179.595333  181.935667  181.935667
# 2019-07  199.210645  201.475161  196.998065  199.582581  199.582581
# 2019-08  185.420645  187.095806  182.878387  184.556774  184.556774
# 2019-09  186.553667  187.662333  183.934667  185.648667  185.648667
# 2019-10  184.387742  186.573548  182.096774  184.438387  184.438387
# 2019-11  195.345667  197.042000  194.109333  195.825667  195.825667
# 2019-12  202.548065  203.706774  200.552258  202.157097  202.157097
# 2020-01  216.316452  217.969677  214.480968  216.468387  216.468387
# 2020-02  207.684138  210.101379  205.300345  207.808621  207.808621
# 2020-03  165.519032  170.464516  160.761290  166.280645  166.280645
# 2020-04  176.213333  178.798000  172.560000  176.320667  176.320667
# 2020-05  207.297333  210.686000  205.196667  208.132667  208.132667
#
#                Volume
# 2019-05  1.068291e+07
# 2019-06  2.008352e+07
# 2019-07  1.572368e+07
# 2019-08  1.348829e+07
# 2019-09  1.362014e+07
# 2019-10  1.376772e+07
# 2019-11  1.289797e+07
# 2019-12  1.379381e+07
# 2020-01  1.530365e+07
# 2020-02  1.716465e+07
# 2020-03  2.955239e+07
# 2020-04  2.545984e+07
# 2020-05  1.940033e+07

# %%
df.resample("W", kind = "period").mean()
# Out:
#                              Open        High         Low       Close  \
# 2019-05-13/2019-05-19  184.892500  187.830000  184.472500  185.722500
# 2019-05-20/2019-05-26  182.941429  184.494286  181.575714  182.415714
# 2019-05-27/2019-06-02  181.612857  182.571429  179.428571  180.425714
# 2019-06-03/2019-06-09  169.285714  171.908571  165.747143  169.742857
# 2019-06-10/2019-06-16  178.381429  180.094286  176.868571  178.488571
# 2019-06-17/2019-06-23  189.030000  191.327143  187.161429  189.701429
# 2019-06-24/2019-06-30  190.910000  193.765714  189.300000  191.085714
# 2019-07-01/2019-07-07  195.010000  196.612857  193.638571  195.942857
# 2019-07-08/2019-07-14  198.922857  202.685714  197.984286  201.934286
# 2019-07-15/2019-07-21  202.715714  203.517143  200.014286  200.772857
# 2019-07-22/2019-07-28  201.092857  204.131429  197.714286  201.328571
# 2019-07-29/2019-08-04  194.115714  196.204286  190.938571  192.428571
# 2019-08-05/2019-08-11  186.942857  188.730000  184.151429  186.442857
# 2019-08-12/2019-08-18  184.338571  186.208571  182.321429  183.888571
# 2019-08-19/2019-08-25  183.201429  184.700000  180.038571  181.260000
# 2019-08-26/2019-09-01  183.710000  184.710000  181.717143  183.714286
# 2019-09-02/2019-09-08  187.798571  188.887143  185.207143  186.938571
# 2019-09-09/2019-09-15  187.640000  188.765714  186.190000  187.494286
# 2019-09-16/2019-09-22  188.902857  190.798571  187.118571  188.910000
# 2019-09-23/2019-09-29  183.081429  183.605714  178.302857  180.330000
# 2019-09-30/2019-10-06  178.011429  179.688571  176.107143  178.460000
# 2019-10-07/2019-10-13  180.598571  183.335714  179.905714  181.411429
# 2019-10-14/2019-10-20  188.187143  190.001429  184.808571  187.094286
# 2019-10-21/2019-10-27  185.880000  188.667143  184.045714  186.900000
# 2019-10-28/2019-11-03  191.957143  193.275714  188.215714  191.352857
# 2019-11-04/2019-11-10  192.265714  193.992857  191.047143  191.932857
# 2019-11-11/2019-11-17  192.905714  194.395714  191.801429  193.674286
# 2019-11-18/2019-11-24  197.585714  199.315714  196.437143  198.374286
# 2019-11-25/2019-12-01  200.588571  202.685714  199.965714  201.097143
# 2019-12-02/2019-12-08  200.155714  201.020000  198.510000  199.962857
# 2019-12-09/2019-12-15  199.162857  200.268571  196.321429  197.650000
# 2019-12-16/2019-12-22  202.774286  204.550000  200.547143  203.395714
# 2019-12-23/2019-12-29  207.268571  208.111429  205.822857  206.930000
# 2019-12-30/2020-01-05  206.320000  208.572857  205.460000  207.242857
# 2020-01-06/2020-01-12  215.380000  217.374286  214.202857  216.194286
# 2020-01-13/2020-01-19  221.497143  222.218571  219.994286  221.472857
# 2020-01-20/2020-01-26  221.378571  222.034286  218.361429  219.782857
# 2020-01-27/2020-02-02  211.785714  213.785714  207.485714  210.164286
# 2020-02-03/2020-02-09  209.134286  211.160000  207.934286  210.281429
# 2020-02-10/2020-02-16  211.582857  213.571429  210.242857  212.384286
# 2020-02-17/2020-02-23  214.642857  216.102857  211.657143  213.512857
# 2020-02-24/2020-03-01  191.594286  197.494286  189.224286  194.550000
# 2020-03-02/2020-03-08  185.884286  189.424286  181.697143  186.075714
# 2020-03-09/2020-03-15  166.915714  172.591429  161.355714  169.034286
# 2020-03-16/2020-03-22  151.070000  156.998571  144.142857  149.244286
# 2020-03-23/2020-03-29  156.662857  160.125714  152.735714  157.000000
# 2020-03-30/2020-04-05  159.547143  162.415714  155.530000  159.011429
# 2020-04-06/2020-04-12  172.398571  174.701429  168.362857  172.774286
# 2020-04-13/2020-04-19  177.627143  179.044286  174.482857  177.700000
# 2020-04-20/2020-04-26  180.697143  185.562857  178.412857  183.808571
# 2020-04-27/2020-05-03  197.710000  201.627143  194.098571  196.588571
# 2020-05-04/2020-05-10  209.031429  211.302857  207.644286  209.872857
# 2020-05-11/2020-05-17  208.288000  211.866000  205.458000  209.214000
#
#                         Adj Close        Volume
# 2019-05-13/2019-05-19  185.722500  1.110232e+07
# 2019-05-20/2019-05-26  182.415714  9.465786e+06
# 2019-05-27/2019-06-02  180.425714  1.295853e+07
# 2019-06-03/2019-06-09  169.742857  2.643721e+07
# 2019-06-10/2019-06-16  178.488571  1.575581e+07
# 2019-06-17/2019-06-23  189.701429  2.447681e+07
# 2019-06-24/2019-06-30  191.085714  1.505194e+07
# 2019-07-01/2019-07-07  195.942857  1.103417e+07
# 2019-07-08/2019-07-14  201.934286  1.496737e+07
# 2019-07-15/2019-07-21  200.772857  1.264260e+07
# 2019-07-22/2019-07-28  201.328571  2.484244e+07
# 2019-07-29/2019-08-04  192.428571  1.524227e+07
# 2019-08-05/2019-08-11  186.442857  1.499441e+07
# 2019-08-12/2019-08-18  183.888571  1.347239e+07
# 2019-08-19/2019-08-25  181.260000  1.299491e+07
# 2019-08-26/2019-09-01  183.714286  1.071593e+07
# 2019-09-02/2019-09-08  186.938571  1.305986e+07
# 2019-09-09/2019-09-15  187.494286  1.252616e+07
# 2019-09-16/2019-09-22  188.910000  1.399901e+07
# 2019-09-23/2019-09-29  180.330000  1.571349e+07
# 2019-09-30/2019-10-06  178.460000  1.304880e+07
# 2019-10-07/2019-10-13  181.411429  1.137123e+07
# 2019-10-14/2019-10-20  187.094286  1.325537e+07
# 2019-10-21/2019-10-27  186.900000  1.079396e+07
# 2019-10-28/2019-11-03  191.352857  2.334133e+07
# 2019-11-04/2019-11-10  191.932857  1.186310e+07
# 2019-11-11/2019-11-17  193.674286  1.153154e+07
# 2019-11-18/2019-11-24  198.374286  1.279854e+07
# 2019-11-25/2019-12-01  201.097143  1.091951e+07
# 2019-12-02/2019-12-08  199.962857  1.115817e+07
# 2019-12-09/2019-12-15  197.650000  1.565659e+07
# 2019-12-16/2019-12-22  203.395714  2.097099e+07
# 2019-12-23/2019-12-29  206.930000  9.377829e+06
# 2019-12-30/2020-01-05  207.242857  1.058194e+07
# 2020-01-06/2020-01-12  216.194286  1.349247e+07
# 2020-01-13/2020-01-19  221.472857  1.364597e+07
# 2020-01-20/2020-01-26  219.782857  1.275813e+07
# 2020-01-27/2020-02-02  210.164286  2.903729e+07
# 2020-02-03/2020-02-09  210.281429  1.356751e+07
# 2020-02-10/2020-02-16  212.384286  1.404609e+07
# 2020-02-17/2020-02-23  213.512857  1.341030e+07
# 2020-02-24/2020-03-01  194.550000  2.578160e+07
# 2020-03-02/2020-03-08  186.075714  2.414397e+07
# 2020-03-09/2020-03-15  169.034286  3.188469e+07
# 2020-03-16/2020-03-22  149.244286  3.549951e+07
# 2020-03-23/2020-03-29  157.000000  2.809314e+07
# 2020-03-30/2020-04-05  159.011429  2.350504e+07
# 2020-04-06/2020-04-12  172.774286  2.509527e+07
# 2020-04-13/2020-04-19  177.700000  2.061540e+07
# 2020-04-20/2020-04-26  183.808571  2.605189e+07
# 2020-04-27/2020-05-03  196.588571  3.348003e+07
# 2020-05-04/2020-05-10  209.872857  1.641470e+07
# 2020-05-11/2020-05-17  209.214000  1.697104e+07

# %%
df.resample("W", kind = "period").agg({"Open": "min", "Close": "max"})
# Out:
#                          Open   Close
# 2019-05-13/2019-05-19  184.84  186.99
# 2019-05-20/2019-05-26  181.88  185.32
# 2019-05-27/2019-06-02  180.28  184.31
# 2019-06-03/2019-06-09  163.71  173.35
# 2019-06-10/2019-06-16  174.75  181.33
# 2019-06-17/2019-06-23  185.01  191.14
# 2019-06-24/2019-06-30  189.54  193.00
# 2019-07-01/2019-07-07  193.00  197.20
# 2019-07-08/2019-07-14  194.97  204.87
# 2019-07-15/2019-07-21  200.15  203.91
# 2019-07-22/2019-07-28  197.63  204.66
# 2019-07-29/2019-08-04  191.10  197.04
# 2019-08-05/2019-08-11  183.60  190.16
# 2019-08-12/2019-08-18  180.95  188.45
# 2019-08-19/2019-08-25  180.84  186.17
# 2019-08-26/2019-09-01  179.40  185.67
# 2019-09-02/2019-09-08  184.00  190.90
# 2019-09-09/2019-09-15  186.46  188.76
# 2019-09-16/2019-09-22  186.66  190.14
# 2019-09-23/2019-09-29  180.49  186.82
# 2019-09-30/2019-10-06  174.84  180.45
# 2019-10-07/2019-10-13  178.26  184.19
# 2019-10-14/2019-10-20  183.80  190.39
# 2019-10-21/2019-10-27  182.01  189.76
# 2019-10-28/2019-11-03  187.20  193.62
# 2019-11-04/2019-11-10  190.00  194.72
# 2019-11-11/2019-11-17  189.93  195.10
# 2019-11-18/2019-11-24  194.56  199.32
# 2019-11-25/2019-12-01  199.52  202.00
# 2019-12-02/2019-12-08  197.60  201.05
# 2019-12-09/2019-12-15  196.40  202.26
# 2019-12-16/2019-12-22  195.27  206.30
# 2019-12-23/2019-12-29  205.57  208.10
# 2019-12-30/2020-01-05  204.00  209.78
# 2020-01-06/2020-01-12  206.70  218.30
# 2020-01-13/2020-01-19  219.60  222.14
# 2020-01-20/2020-01-26  220.75  222.14
# 2020-01-27/2020-02-02  206.53  223.23
# 2020-02-03/2020-02-09  203.44  212.33
# 2020-02-10/2020-02-16  207.85  214.18
# 2020-02-17/2020-02-23  213.48  217.80
# 2020-02-24/2020-03-01  182.70  200.72
# 2020-03-02/2020-03-08  178.33  196.44
# 2020-03-09/2020-03-15  159.54  178.19
# 2020-03-16/2020-03-22  139.75  153.13
# 2020-03-23/2020-03-29  149.66  163.34
# 2020-03-30/2020-04-05  157.15  166.80
# 2020-04-06/2020-04-12  160.15  175.19
# 2020-04-13/2020-04-19  173.67  179.24
# 2020-04-20/2020-04-26  175.25  190.07
# 2020-04-27/2020-05-03  188.66  204.71
# 2020-05-04/2020-05-10  200.20  212.35
# 2020-05-11/2020-05-17  202.56  213.18
